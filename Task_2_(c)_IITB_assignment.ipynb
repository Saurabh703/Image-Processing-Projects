# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabh703/Image-Processing-Projects/blob/master/Task_2_(c)_IITB_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 2 (c)
#
# ### Task: For WSIROIS dataset

# %%
pip install openslide-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wholeslidedata as ws
import numpy as np
import matplotlib.pyplot as plt
import os
os.add_dll_directory("/Program Files/openslide/bin")

import openslide
from openslide import open_slide

# %%
slide = open_slide('134B.tif')

slide_props = slide.properties # properties of slide
print(slide_props)
# Out:
# <_PropertyMap {'openslide.level-count': '9', 'openslide.level[0].downsample': '1', 'openslide.level[0].height': '26240', 'openslide.level[0].tile-height': '512', 'openslide.level[0].tile-width': '512', 'openslide.level[0].width': '97216', 'openslide.level[1].downsample': '2', 'openslide.level[1].height': '13120', 'openslide.level[1].tile-height': '512', 'openslide.level[1].tile-width': '512', 'openslide.level[1].width': '48608', 'openslide.level[2].downsample': '4', 'openslide.level[2].height': '6560', 'openslide.level[2].tile-height': '512', 'openslide.level[2].tile-width': '512', 'openslide.level[2].width': '24304', 'openslide.level[3].downsample': '8', 'openslide.level[3].height': '3280', 'openslide.level[3].tile-height': '512', 'openslide.level[3].tile-width': '512', 'openslide.level[3].width': '12152', 'openslide.level[4].downsample': '16', 'openslide.level[4].height': '1640', 'openslide.level[4].tile-height': '512', 'openslide.level[4].tile-width': '512', 'openslide.level[4].wi
# ...

# %%
slide_dims = slide.dimensions
print(slide_dims)
# Out:
# (97216, 26240)

# %%
slide_thumb_600 = slide.get_thumbnail(size=(600, 600))

# %%
slide_thumb_600_np = np.array(slide_thumb_600)
plt.figure(figsize=(8,8))
plt.imshow(slide_thumb_600_np)

# %%
from wholeslidedata import WholeSlideAnnotation
from wholeslidedata.visualization.plotting import plot_annotations
# from colour import Color
from matplotlib import pyplot as plt

# %%
wsa = WholeSlideAnnotation('134B.xml')

# %%
wsi = open_slide('134B.tif')

# %%
print(len(wsa.annotations))
print(wsa.labels.names)
# Out:
# 587
# ['inflamed stroma', 'invasive tumor', 'rest', 'tumor-associated stroma', 'lymphocytes and plasma cells', 'roi']

# %%
plot_annotations(wsa.annotations)

# %%
# Extraction and display of ‘Tumor-associated Stroma’ region in the WSI 
tumor_annotations = [annotation for annotation in wsa.annotations if annotation.label.name == "tumor-associated stroma"]
fig = plt.subplots(1,1)
plot_annotations(tumor_annotations)
plt.show()

# %%
# Iterate over each 'Tumor-associated Stroma' region and count number of lymphocytes
lymphocyte_count = 0
for stroma_region in tumor_annotations:
    # Count number of lymphocytes
    lymphocytes = tumor_annotations
    lymphocyte_count += len(lymphocytes)

# Print total number of lymphocytes in all 'Tumor-associated Stroma' regions
print("Total number of lymphocytes in 'Tumor-associated Stroma' regions:", lymphocyte_count)
# Out:
# Total number of lymphocytes in 'Tumor-associated Stroma' regions: 9
